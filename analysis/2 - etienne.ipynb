# %% [markdown]
# ###: this file should read the data from consolidated.csv
#
# ###:this should do all of the analysis

# %% [markdown]
# ### :General Note - Any Analysis that can be done for cases can be done for deaths, although cases might be easier because the data aren't lagged
# Timeframe - Jan 2019 - Today
# "Pre COVID" = Jan 2019 - Mar 2020
#
#
# **Question 1: How did COVID Change Overall Travel Patterns?**
#
# 1) Plot 1: Scatter Plot (Points = States, X-Axis = Travel Volume, Y-Axis = Cases)
#
# 2) Plot 2: Line Graph (X-Axis = Time, Y-Axis = Travel Volume, COVID Cases)
#
# **Question 2: Which States reacted most/least aggressively to COVID (largest change in travel patterns)**
#
# 1) Plot 1: (Pick 2 states, e.g. CA, TX) - Time Series of COVID Cases and Travel Volume (Overlay 2019 and 2020)
#
# 2) Plot 2: State Specific Bar Graph showing travel before / travel after (FL - 80% / 60% "pop not stay at home"), potentially all 50 states
#
# **Question 3: How did COVID change the nature / length of travel?**
#
# 1) Plot 1: Time Series of Trip Type over Time (Nationally)
#
# 2) Plot 2: Scatter Plot of Counties that Changed the Most
#
# **Question 4: Did Reducing Travel Reduce COVID**
#
# 1) Plot 1: Bar graph (by state) PRE-COVID Trips vs. COVID Trips (timeframe TBD)
#
# 2) Plot 2: TBD

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import numpy as np

# %%
path = "output_data/consolidated_new.csv"
covid_df = pd.read_csv(path)
covid_df
# Out:
#       state  tot_cases  new_case  tot_death  new_death        Date  \
# 0        MO          0       NaN          0        NaN  2019-01-01
# 1        LA          0       NaN          0        NaN  2019-01-01
# 2        AZ          0       NaN          0        NaN  2019-01-01
# 3        AR          0       NaN          0        NaN  2019-01-01
# 4        CA          0       NaN          0        NaN  2019-01-01
# ...     ...        ...       ...        ...        ...         ...
# 53800    SD     162375       0.0       2305        0.0  2021-11-20
# 53801    CA    5014428       0.0      73000        0.0  2021-11-20
# 53802    OH    1639070    5590.0      26063        0.0  2021-11-20
# 53803    UT     582929       0.0       3428        0.0  2021-11-20
# 53804    GA    1654649       0.0      30162        0.0  2021-11-20
#
#        Population Staying at Home  Population Not Staying at Home  \
# 0                       1530765.0                       4576960.0
# 1                       1042471.0                       3603260.0
# 2                       1721026.0                       5428700.0
# 3                        642665.0                       2361951.0
# 4                       9212440.0                      30223696.0
# ...                           ...                             ...
# 53800                    171947.0                        712712.0
# 53801                  10043294.0                      29468929.0
# 53802                   2448434.0                       9240666.0
# 53803                    716625.0                       2489333.0
# 53804                   2198559.0                       8418864.0
#
#        Number of Trips  Number of Trips <1  ...  Number of Trips 25-50  \
# 0           16618431.0           4033851.0  ...               809030.0
# 1           13635299.0           3737562.0  ...               530891.0
# 2           18705619.0           5351386.0  ...               865350.0
# 3            7488494.0           1715475.0  ...               347585.0
# 4          111648618.0          33567702.0  ...              5318558.0
# ...                ...                 ...  ...                    ...
# 53800        3636567.0           1091024.0  ...               178228.0
# 53801      123467116.0          34174699.0  ...              6447071.0
# 53802       52206417.0          15961931.0  ...              1923585.0
# 53803       12783889.0           3492150.0  ...               667482.0
# 53804       39211498.0          10923108.0  ...              2075629.0
#
#        Number of Trips 50-100  Number of Trips 100-250  \
# 0                    290444.0                 154169.0
# 1                    249210.0                  97879.0
# 2                    278933.0                 190394.0
# 3                    154771.0                  67697.0
# 4                   2111397.0                 750377.0
# ...                       ...                      ...
# 53800                100882.0                  49912.0
# 53801               2787076.0                1054817.0
# 53802                785995.0                 319374.0
# 53803                225500.0                  99433.0
# 53804                756789.0                 383302.0
#
#        Number of Trips 250-500  Number of Trips >=500  total_population  \
# 0                      39949.0                29170.0         6107725.0
# 1                      22007.0                14093.0         4645731.0
# 2                      39342.0                43397.0         7149726.0
# 3                      16563.0                 7904.0         3004616.0
# 4                     178478.0               214788.0        39436136.0
# ...                        ...                    ...               ...
# 53800                   5480.0                 2510.0          884659.0
# 53801                 234871.0               134765.0        39512223.0
# 53802                  45441.0                29849.0        11689100.0
# 53803                  29599.0                16726.0         3205958.0
# 53804                  89867.0                38518.0        10617423.0
#
#        tot_cases%  tot_death%  Population Staying at Home%  \
# 0        0.000000    0.000000                    25.062769
# 1        0.000000    0.000000                    22.439332
# 2        0.000000    0.000000                    24.071216
# 3        0.000000    0.000000                    21.389256
# 4        0.000000    0.000000                    23.360402
# ...           ...         ...                          ...
# 53800   18.354530    0.260552                    19.436529
# 53801   12.690827    0.184753                    25.418195
# 53802   14.022209    0.222968                    20.946300
# 53803   18.182677    0.106926                    22.352913
# 53804   15.584281    0.284080                    20.707087
#
#        Population Not Staying at Home%
# 0                            74.937231
# 1                            77.560668
# 2                            75.928784
# 3                            78.610744
# 4                            76.639598
# ...                                ...
# 53800                        80.563471
# 53801                        74.581805
# 53802                        79.053700
# 53803                        77.647087
# 53804                        79.292913
#
# [53805 rows x 24 columns]

# %%
CA_COVID_1 = covid_df[covid_df['state']== "CA"]
CA_COVID_2 = CA_COVID_1[CA_COVID_1['tot_cases']!= 0]
CA_COVID_3 = CA_COVID_2.dropna()
CA_COVID_3.head()
# Out:
#       state  tot_cases  new_case  tot_death  new_death        Date  \
# 20247    CA          3       3.0          0        0.0  2020-02-02
# 20337    CA          6       3.0          0        0.0  2020-02-03
# 20368    CA          6       0.0          0        0.0  2020-02-04
# 20434    CA          6       0.0          0        0.0  2020-02-05
# 20458    CA          6       0.0          0        0.0  2020-02-06
#
#        Population Staying at Home  Population Not Staying at Home  \
# 20247                   8674130.0                      30882915.0
# 20337                   7516164.0                      32040881.0
# 20368                   7404908.0                      32152137.0
# 20434                   7389989.0                      32167056.0
# 20458                   7369817.0                      32187228.0
#
#        Number of Trips  Number of Trips <1  ...  Number of Trips 25-50  \
# 20247      120969857.0          32769671.0  ...              5779739.0
# 20337      137082176.0          37437085.0  ...              7226417.0
# 20368      137334133.0          37302419.0  ...              7365334.0
# 20434      140458490.0          38769455.0  ...              7324225.0
# 20458      142169443.0          39324618.0  ...              7431876.0
#
#        Number of Trips 50-100  Number of Trips 100-250  \
# 20247               2224657.0                 880903.0
# 20337               2406472.0                 860342.0
# 20368               2429285.0                 792546.0
# 20434               2416066.0                 788039.0
# 20458               2447328.0                 790135.0
#
#        Number of Trips 250-500  Number of Trips >=500  total_population  \
# 20247                 214320.0               147714.0        39557045.0
# 20337                 205845.0               154855.0        39557045.0
# 20368                 198781.0               159265.0        39557045.0
# 20434                 210519.0               165528.0        39557045.0
# 20458                 215653.0               164722.0        39557045.0
#
#        tot_cases%  tot_death%  Population Staying at Home%  \
# 20247    0.000008         0.0                    21.928155
# 20337    0.000015         0.0                    19.000823
# 20368    0.000015         0.0                    18.719568
# 20434    0.000015         0.0                    18.681853
# 20458    0.000015         0.0                    18.630858
#
#        Population Not Staying at Home%
# 20247                        78.071845
# 20337                        80.999177
# 20368                        81.280432
# 20434                        81.318147
# 20458                        81.369142
#
# [5 rows x 24 columns]

# %%
TX_COVID_1 = covid_df[covid_df['state']== "TX"]
TX_COVID_2 = TX_COVID_1[TX_COVID_1['tot_cases']!= 0]
TX_COVID_3 = TX_COVID_2.dropna()

# %%
TX_COVID_3['new_case'].plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
from IPython.display import display
plot_data = {}
for state in ['CA',"TX","IL","NY","FL"]:
    df = covid_df[covid_df.state == state]
    df.index = pd.to_datetime(df.Date)
    plot_data[state] = df[['new_case','Number of Trips']].dropna()

# %%
plot_data['IL'].plot(label='IL',figsize=(10,5))
sns.despine()
plt.title('New Covid Cases - IL')
plt.legend()

# %%
tx = plot_data['TX']
tx['month'] = tx.index.month

# %%
tx
# Out:
#             new_case  Number of Trips  month
# Date
# 2020-01-22       0.0       94342336.0      1
# 2020-01-23       0.0      100218909.0      1
# 2020-01-24       0.0      107179008.0      1
# 2020-01-25       0.0       97779266.0      1
# 2020-01-26       0.0       87097238.0      1
# ...              ...              ...    ...
# 2021-11-16    4301.0      109844231.0     11
# 2021-11-17    4867.0      114412236.0     11
# 2021-11-18    4744.0       99736696.0     11
# 2021-11-19    4370.0      113499656.0     11
# 2021-11-20    2670.0      101777527.0     11
#
# [669 rows x 3 columns]

# %%
txdiff = tx.diff()

# %%
txdiff['month'] = tx['month']

# %%
sns.lmplot(
    data=tx,
    x="new_case", y='Number of Trips', hue="month",
    height=5
)
plt.title("Texas New Cases vs. Trips (month by month)")
# Out:
# Text(0.5, 1.0, 'Texas New Cases vs. Trips (month by month)')

# %%
plot_data['TX'].plot(label='TX',figsize=(10,5))
sns.despine()
plt.title('New Covid Cases - TX')
plt.legend()

# %%
plot_data['CA'].plot(label='CA',figsize=(10,5))
sns.despine()
plt.title('New Covid Cases - CA')
plt.legend();

# %%
plot_data['NY'].plot(label='NY',figsize=(10,5))
sns.despine()
plt.title('New Covid Cases - NY')
plt.legend();

# %%
plot_data['FL'].plot(label="FL",figsize=(10,5))
sns.despine()
plt.title('New Covid Cases - FL')
plt.legend();

# %%
frame = pd.DataFrame()
for key in plot_data.keys():
    frame[key] = plot_data[key]

# %%
frame.plot(subplots=True)

# %%
differenced = frame.diff()

# %%
pd.plotting.scatter_matrix(frame,figsize=(12,8));
plt.title('Daily Change in New Cases - State vs. State')

# %%
frame['day'] = frame.index.day_name()

# %%
frame['month'] = frame.index.month

# %%
sns.pairplot(frame,kind="reg",hue='day')

# %%
sns.pairplot(frame,hue='day')
sns.color_palette("hls", 8);

# %%
frame2 = frame[['CA', 'TX', 'IL', 'NY', 'FL', 'dtime']]

# %%
frame.columns

# %%
frame['dtime'] = frame.index

# %%
sns.pairplot(frame2,hue='dtime',palette='viridis', diag_kind=None)
# sns.color_palette("flare", as_cmap=True)
# sns.color_palette("viridis", as_cmap=True);

# %%
frame

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
frame2['dtime'] = frame2.dtime.astype('str')

# %%
sns.lmplot(
    data=frame,
    x="NY", y="FL", hue="month",
    height=5
)

# %%
sns.lmplot(
    data=frame,
    x="IL", y="TX", hue="month",
    height=5
)

# %%
states = ['CA', 'TX', 'IL', 'NY', 'FL']

# %%
frame[states].rolling(7).mean().plot()

# %%
detrended = frame[states].rolling(7).mean()

# %%
detrended['month'] = frame.month

# %%
sns.lmplot(
    data=detrended,
    x="IL", y="TX", hue="month",
    height=5
)

# %%
sns.lmplot(
    data=detrended,
    x="NY", y="FL", hue="month",
    height=5
)
